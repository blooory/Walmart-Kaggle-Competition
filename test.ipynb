# %%
import pandas as pd
import numpy as np
import scipy
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cross_validation import StratifiedShuffleSplit
from matplotlib import rc


font = {'family': 'Droid Sans'}
rc('font', **font)

# %%
tr = pd.read_csv('./Data/train.csv')
te = pd.read_csv('./Data/test.csv')
# Убираю маленький класс, поможет избежать кучи ворнингов. Ещё нужно решить нужно ли так делать
tr = tr[tr.TripType != 14]

# %%
visits = tr.drop_duplicates('VisitNumber')[['VisitNumber', 'TripType']]
a = StratifiedShuffleSplit(visits['TripType'], n_iter = 1, test_size =0.3, random_state = 2222)
tr, te = (tr[tr.VisitNumber.isin(visits.iloc[list(a)[0][0]]['VisitNumber'])],
          tr[tr.VisitNumber.isin(visits.iloc[list(a)[0][1]]['VisitNumber'])])

# %%
feature = 'FinelineNumber'
# feature = 'DepartmentDescription'
# feature = 'Upc'
counts = tr[feature].append(te[feature]).value_counts()

# %%
restriction = set(tr[feature].unique()).intersection(set(te[feature].unique()))

# %%
count_thr = 1
def foo(x,feature):
    l = ''
    for t, row in x.iterrows():
        l += (str(row[feature]).replace(' ','').replace(',','') + ' ') * row['ScanCount'] 
    return l
sentences_tr = tr[(tr[feature].isin(counts[counts>count_thr].index)) & 
                 (tr[feature].isin(restriction))].groupby('VisitNumber').apply(lambda x: foo(x, feature))
sentences_te = te[(te[feature].isin(counts[counts>count_thr].index)) &
                 (te[feature].isin(restriction))].groupby('VisitNumber').apply(lambda x: foo(x, feature))
temp_tr = tr[(tr[feature].isin(counts[counts>count_thr].index)) & 
                 (tr[feature].isin(restriction))].drop_duplicates('VisitNumber').reset_index(drop=True)
temp_te = te[(te[feature].isin(counts[counts>count_thr].index)) &
                 (te[feature].isin(restriction))].drop_duplicates('VisitNumber').reset_index(drop=True)

# %%
tt = TfidfTransformer()
cv = CountVectorizer()
cv.fit(sentences_tr.append(sentences_te))
counts_tr = cv.transform(sentences_tr)
counts_te = cv.transform(sentences_te)
counts_all = cv.transform(sentences_tr.append(sentences_te))
tt.fit(counts_all)
tfidf_tr = tt.transform(counts_tr)
tfidf_te = tt.transform(counts_te)

# %% [markdown]
# ### Stratified k-fold nearest neighbours

# %%
from sklearn.cross_validation import StratifiedKFold
from sklearn.neighbors import NearestNeighbors
nn_folds = StratifiedKFold(temp_tr['TripType'], n_folds=4, shuffle=True, random_state=406)
nn = NearestNeighbors(4, metric = 'cosine', algorithm = 'brute')
features_tr = temp_tr['VisitNumber'].to_frame().copy()
features_te = temp_te['VisitNumber'].to_frame().copy()
for train_index, test_index in nn_folds:
    for i in sorted(temp_tr.TripType.unique()):
        if i != 14:
            nn.fit(tfidf_tr[temp_tr.loc[train_index][temp_tr.TripType == i].index])
            features_tr.loc[test_index, feature + '_distance_to_' + str(i)] = np.mean(nn.kneighbors(tfidf_tr[test_index])[0][:, 2:5], axis = 1)
        else:
            nn = NearestNeighbors(2, metric = 'cosine', algorithm = 'brute')
            nn.fit(tfidf_tr[temp_tr.loc[train_index][temp_tr.TripType == i].index])
            features_tr.loc[test_index, feature + '_distance_to_' + str(i)] = nn.kneighbors(tfidf_tr[test_index])[0][:, 1]
            nn = NearestNeighbors(4, metric = 'cosine', algorithm = 'brute')
            
for i in sorted(temp_tr.TripType.unique()):
    nn.fit(tfidf_tr[temp_tr[temp_tr.TripType == i].index])
    if i == 14:
        nn = NearestNeighbors(3, metric = 'cosine', algorithm = 'brute')
        nn.fit(tfidf_tr[temp_tr[temp_tr.TripType == i].index])
        features_te.loc[:, feature + '_distance_to_' + str(i)] = nn.kneighbors(tfidf_te)[0][:, 1]
        nn = NearestNeighbors(4, metric = 'cosine', algorithm = 'brute')
    else:
        features_te.loc[:, feature + '_distance_to_' + str(i)] = np.mean(nn.kneighbors(tfidf_te)[0][:, 2:5], axis = 1)
# Out:
# /opt/conda/Anaconda3/lib/python3.4/site-packages/sklearn/cross_validation.py:516: Warning: The least populated class in y has only 3 members, which is too few. The minimum number of labels for any class cannot be less than n_folds=4.
#   % (min_labels, self.n_folds)), Warning)
# /opt/conda/Anaconda3/lib/python3.4/site-packages/pandas/core/frame.py:1997: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   "DataFrame index.", UserWarning)

# %%
# %%time
# Ближайший сосед без фолдов
features_tr = temp_tr['VisitNumber'].to_frame().copy()
features_te = temp_te['VisitNumber'].to_frame().copy()
for i in sorted(temp_tr.TripType.unique()):
    nn.fit(tfidf_tr[temp_tr[temp_tr.TripType == i].index])
    if i == 14:
        nn = NearestNeighbors(3, metric = 'cosine', algorithm = 'brute')
        nn.fit(tfidf_tr[temp_tr[temp_tr.TripType == i].index])
        features_tr.loc[:, feature + '_distance_to_' + str(i)] = nn.kneighbors(tfidf_tr)[0][:, 2]
        features_te.loc[:, feature + '_distance_to_' + str(i)] = nn.kneighbors(tfidf_te)[0][:, 1]
        nn = NearestNeighbors(4, metric = 'cosine', algorithm = 'brute')
        nn.fit(tfidf_tr[temp_tr[temp_tr.TripType == i].index])
    else:
        features_tr.loc[:, feature + '_distance_to_' + str(i)] = np.mean(nn.kneighbors(tfidf_tr)[0][:, 3:5], axis = 1)
        features_te.loc[:, feature + '_distance_to_' + str(i)] = np.mean(nn.kneighbors(tfidf_te)[0][:, 2:5], axis = 1)
# Out:
# CPU times: user 57.2 s, sys: 22.1 s, total: 1min 19s
# Wall time: 1min 19s

# %%
# Сравнение средних расстояний до соседей между тестом и трейном
(features_tr.mean() - features_te.mean()).iloc[1:].describe()
# Out:
# count    38.000000
# mean      0.020169
# std       0.007233
# min       0.000005
# 25%       0.017611
# 50%       0.020019
# 75%       0.024209
# max       0.040600
# dtype: float64

# %%
# Расчет расстояний для картинки
l = list()
for j in sorted(temp_tr.TripType.unique()):
    if j != 14:
        nn = NearestNeighbors(4, metric = 'cosine', algorithm = 'brute')
        nn.fit(tfidf_tr[temp_tr[temp_tr.TripType == j].index])
        qq = nn.kneighbors(tfidf_te)[0]
        temp = list()

        for i in sorted(temp_tr.TripType.unique()):
            if i != 14:
                temp.append(np.mean(qq[:, 3:5][temp_te[temp_te.TripType == i].index]))
        l.append(temp)

# %%
# %matplotlib inline

# %%
from matplotlib.ticker import MaxNLocator
import matplotlib.pyplot as plt
fig, ax  = plt.subplots(figsize=(14,13))
x = np.array(list(range(1,39)))*1.021
y = np.array(list(range(1,39)))*1.021
#setup the 2D grid with Numpy
x, y = np.meshgrid(x, y)
#convert intensity (list of lists) to a numpy array for plotting
l = np.array(l)
plt.xlim([0, 41])
plt.ylim([0, 41])
#now just plug the data into pcolormesh, it's that easy!
plt.pcolormesh(x, y, l, cmap = 'viridis')
plt.colorbar() #need a colorbar to show the intensity scale
ax.xaxis.set_major_locator(MaxNLocator(41))
ax.yaxis.set_major_locator(MaxNLocator(41))
plt.ylabel('Класс из обучающей выборки')
plt.xlabel('Класс из валидационной выборки')
ax.set_xticklabels([0]+sorted(temp_tr.TripType.unique()))
ax.set_yticklabels([0]+sorted(temp_tr.TripType.unique()))
plt.show() #boom

# %%
features_tr.to_pickle('./Data/tfidif_tr_val')
features_te.to_pickle('./Data/tfidif_te_val')

# %%
features_tr = pd.read_pickle('./Data/tfidif_tr_val')
features_te = pd.read_pickle('./Data/tfidif_te_val')

# %% [markdown]
# # Ridge classifier features

# %%
# Для риджа нужны тф-идф фичи и файлы с номерами походов в магазины
from sklearn.linear_model import RidgeClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.cross_validation import StratifiedKFold
from sklearn.metrics import log_loss
from sklearn.linear_model import SGDClassifier
num_folds = 9

nn_ridge = StratifiedKFold(temp_tr['TripType'], n_folds=num_folds, shuffle=True, random_state=406)
# rr = RidgeClassifier(alpha=1., fit_intercept=True, 
#                       normalize=True, 
#                       copy_X=True, max_iter=None, 
#                       tol=0.00001, class_weight=None, solver='auto')
rr = SGDClassifier(loss='log', 
                   penalty='l2', 
                   alpha=0.000001, 
                   l1_ratio=0.15,
                   fit_intercept=True, 
                   n_iter=50, 
                   shuffle=True, 
                   verbose=0, 
                   epsilon=0.1, 
                   n_jobs=-1, 
                   random_state=None, 
                   learning_rate='optimal', 
                   eta0=0.0, 
                   power_t=0.5, 
                   class_weight=None, 
                   warm_start=False, 
                   average=True)
features_ridge = ['Ridge_'+str(x) for x in sorted(tr.TripType.unique())]
for i in features_ridge:
    temp_tr.loc[:, i] = 0
    temp_te.loc[:, i] = 0
qq = 1
for train_index, test_index in nn_ridge:
    rr.fit(tfidf_tr[train_index],temp_tr.iloc[train_index]['TripType'])
    d = rr.decision_function(tfidf_tr[test_index])
    probs_train = np.exp(d) / (1 + np.exp(d))
    for i in range(len(features_ridge)):
        temp_tr.loc[:, features_ridge[i]].iloc[test_index] = probs_train[:,i]
    d = rr.decision_function(tfidf_te)
    probs = np.exp(d) / (1 + np.exp(d))
    temp_te.loc[:, features_ridge] += probs
    print('Iteration {0}, validation loss - {1}, train loss {2}'.format(qq,
                                                                        log_loss(temp_te['TripType'], probs),
                                                                        log_loss(temp_tr.iloc[test_index]['TripType'], probs_train)))
    qq += 1
# # Если нужно считать ридж вероятности не по фолдам, а по всему трейну
# rr.fit(tr.drop(labels = ['TripType', 'VisitNumber'], axis = 1),tr['TripType'])
# d = rr.decision_function(te.drop(labels = ['TripType', 'VisitNumber'], axis = 1))
# probs = np.exp(d) / (1 + np.exp(d))
# te.loc[:, features_ridge] = probs
print('Final validation loss {0}'.format(log_loss(temp_te['TripType'], temp_te.loc[:, features_ridge].as_matrix() )))
# Для удобства и ввиду наличия свободной памяти запишу фичи в отдельную переменную
features_ridge_tr = temp_tr[features_ridge+['VisitNumber']].copy()
features_ridge_te = temp_te[features_ridge+['VisitNumber']].copy()

# Нормализация вероятностей риджа
cols_ridge = list(features_ridge_tr.columns)
cols_ridge.remove('VisitNumber')
qq = np.sum(features_ridge_tr[cols_ridge].as_matrix(),axis = 1)
features_ridge_tr.loc[:,cols_ridge] = features_ridge_tr[cols_ridge].apply(lambda x: x/qq, axis = 0)
qq = np.sum(features_ridge_te[cols_ridge].as_matrix(),axis = 1)
features_ridge_te.loc[:,cols_ridge] = features_ridge_te[cols_ridge].apply(lambda x: x/qq, axis = 0)
# Out:
# Iteration 1, validation loss - 1.6071302374981655, train loss 1.6123224103832878
# Iteration 2, validation loss - 1.6027233747474854, train loss 1.603007188913984
# Iteration 3, validation loss - 1.6080150362155963, train loss 1.6465023085871688
# Iteration 4, validation loss - 1.6064407283975186, train loss 1.6189416683148155
# Iteration 5, validation loss - 1.6053827743666846, train loss 1.6435493641741055
# Iteration 6, validation loss - 1.6050867669953894, train loss 1.591081239408098
# Iteration 7, validation loss - 1.6103098271666045, train loss 1.6237653294400807
# Iteration 8, validation loss - 1.606346368815508, train loss 1.616896307740524
# Iteration 9, validation loss - 1.6034838440629056, train loss 1.5956936405754683
# Final validation loss 1.7439213099818915
# /opt/conda/Anaconda3/lib/python3.4/site-packages/pandas/core/indexing.py:117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %% [markdown]
# # KNN tf-idf features

# %%
import xgboost as xgb
from sklearn.cross_validation import StratifiedKFold

# %%
rr = xgb.XGBClassifier(max_depth=130, 
                       learning_rate=0.5, 
                       n_estimators=5, 
                       silent=True, 
                       objective='multi:softprob', 
                       nthread=-1, 
                       gamma=0, 
                       min_child_weight=1, 
                       max_delta_step=0, 
                       subsample=1, 
                       colsample_bytree=0.8, 
                       base_score=0.027, 
                       seed=0, missing=None)

# %%
from sklearn.naive_bayes import GaussianNB
rr = GaussianNB()

# %%
tfidf_te = tfidf_te.todense()
tfidf_tr = tfidf_tr.todense()

# %%
# %%time
from sklearn.neighbors import KNeighborsClassifier
from sklearn.cross_validation import StratifiedKFold
import xgboost as xgb

num_folds = 7
num_nn = 2
num_test_parts = 10

nn_ridge = StratifiedKFold(temp_tr['TripType'], n_folds=num_folds, shuffle=True, random_state=406)
# rr = KNeighborsClassifier(n_neighbors=num_nn, 
#                                        algorithm='brute', 
#                                        metric='cosine', n_jobs=-1)
features_knn = ['KNN_'+str(x) for x in sorted(tr.TripType.unique())]
# Создаю столбцы
for i in features_knn:
    temp_tr.loc[:, i] = 0
    temp_te.loc[:, i] = 0

qq = 1
for train_index, test_index in nn_ridge:
    print('Fold {0}'.format(qq))
    qq += 1
    rr.fit(tfidf_tr[train_index],temp_tr.iloc[train_index]['TripType'])
    d = rr.predict_proba(tfidf_tr[test_index])
    # Очередной тупняк пандаса, который не хочет присваивать сразу набору столбцов значение, поэтому цикл
    for i in range(len(features_knn)):
        temp_tr.loc[:, features_knn[i]].iloc[test_index] = d[:,i]
    # Почему-то кнн не хочет предсказывать для большого теста результат. Разделю тест на n частей
    batch_size = int(tfidf_te.shape[0]/num_test_parts)
    for i in range(num_test_parts):
        if i!=(num_test_parts-1):
            ind = range(batch_size*i, batch_size*(i+1))
        else: ind = range(batch_size*i, tfidf_te.shape[0])
        d = rr.predict_proba(tfidf_te[ind])
        for i in range(len(features_knn)):
            temp_te.loc[:, features_knn[i]].iloc[ind] += d[:,i]

features_knn_tr = temp_tr[features_knn+['VisitNumber']].copy()
features_knn_te = temp_te[features_knn+['VisitNumber']].copy()
cols_knn= list(features_knn_tr.columns)
cols_knn.remove('VisitNumber')
qq = np.sum(features_knn_tr[cols_knn].as_matrix(),axis = 1)
features_knn_tr.loc[:,cols_knn] = features_knn_tr[cols_knn].apply(lambda x: x/qq, axis = 0)
qq = np.sum(features_knn_te[cols_knn].as_matrix(),axis = 1)
features_knn_te.loc[:,cols_knn] = features_knn_te[cols_knn].apply(lambda x: x/qq, axis = 0)
# Out:
# Fold 1
# Fold 2
# Fold 3
# Fold 4
# Fold 5
# Fold 6
# Fold 7
# CPU times: user 5min 49s, sys: 3min 41s, total: 9min 30s
# Wall time: 9min 30s
# /opt/conda/Anaconda3/lib/python3.4/site-packages/pandas/core/indexing.py:117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
tfidf_te.shape
# Out:
# (20985, 5323)

# %% [markdown]
# ## Запись и чтение промежуточных результатов по фичам

# %%
features_ridge_tr.to_pickle('ridge_features_tr_val_9')
features_ridge_te.to_pickle('ridge_features_te_val_9')

# %%
features_ridge_tr.to_pickle('ridge_features_tr_val_9_depdesk')
features_ridge_te.to_pickle('ridge_features_te_val_9_depdesk')

# %%
features_ridge_tr.to_pickle('ridge_features_tr_val_9_upc')
features_ridge_te.to_pickle('ridge_features_te_val_9_upc')

# %%
features_knn_tr.to_pickle('knn_features_tr_val_7_25n')
features_knn_te.to_pickle('knn_features_te_val_7_25n')

# %%
features_ridge_tr = pd.read_pickle('ridge_features_tr_val_9')
features_ridge_te = pd.read_pickle('ridge_features_te_val_9')

# %%
features_knn_tr = pd.read_pickle('knn_features_tr_val_9_20n')
features_knn_te = pd.read_pickle('knn_features_te_val_9_20n')

# %%
features_ridge_tr = pd.read_pickle('ridge_features_tr_val_9_depdesk')
features_ridge_te = pd.read_pickle('ridge_features_te_val_9_depdesk')

# %%
features_ridge_tr = pd.read_pickle('ridge_features_tr_val_9_upc')
features_ridge_te = pd.read_pickle('ridge_features_te_val_9_upc')

# %%
features_tr.to_pickle('distance_features_tr_val_35n')
features_te.to_pickle('distance_features_te_val_25n')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-d5ef848caf90> in <module>()
# ----> 1 features_tr.to_pickle('distance_features_tr_val_35n')
#       2 features_te.to_pickle('distance_features_te_val_25n')
#
# NameError: name 'features_tr' is not defined

# %%
features_tr= pd.read_pickle('distance_features_tr_val_35n')
features_te=pd.read_pickle('distance_features_te_val_25n')

# %% [markdown]
# # Формирование датасета

# %%
# Для паблика
tr = pd.read_pickle('./Data/tr_aggregates')
te = pd.read_pickle('./Data/te_aggregates')

# %%
# Вытаскиваем из трейна валидацию
train = pd.read_pickle('./Data/tr_aggregates')
tr, te = (train[train.VisitNumber.isin(visits.iloc[list(a)[0][0]]['VisitNumber'])],
          train[train.VisitNumber.isin(visits.iloc[list(a)[0][1]]['VisitNumber'])])

# %%
tr = tr.merge(features_tr, how = 'left', on = 'VisitNumber').fillna(1)
te = te.merge(features_te, how = 'left', on = 'VisitNumber').fillna(1)
# tr = tr.merge(features_knn_tr, how = 'left', on = 'VisitNumber').fillna(0)
# te = te.merge(features_knn_te, how = 'left', on = 'VisitNumber').fillna(0)
tr = tr.merge(features_ridge_tr, how = 'left', on = 'VisitNumber').fillna(0)
te = te.merge(features_ridge_te, how = 'left', on = 'VisitNumber').fillna(0)

# %%
# 3 набора фичей риджа
features_ridge_tr = pd.read_pickle('ridge_features_tr_val_9')
features_ridge_te = pd.read_pickle('ridge_features_te_val_9')
tr = tr.merge(features_ridge_tr, how = 'left', on = 'VisitNumber').fillna(0)
te = te.merge(features_ridge_te, how = 'left', on = 'VisitNumber').fillna(0)
features_ridge_tr = pd.read_pickle('ridge_features_tr_val_9_depdesk')
features_ridge_te = pd.read_pickle('ridge_features_te_val_9_depdesk')
tr = tr.merge(features_ridge_tr, how = 'left', on = 'VisitNumber').fillna(0)
te = te.merge(features_ridge_te, how = 'left', on = 'VisitNumber').fillna(0)
features_ridge_tr = pd.read_pickle('ridge_features_tr_val_9_upc')
features_ridge_te = pd.read_pickle('ridge_features_te_val_9_upc')
tr = tr.merge(features_ridge_tr, how = 'left', on = 'VisitNumber').fillna(0)
te = te.merge(features_ridge_te, how = 'left', on = 'VisitNumber').fillna(0)

# %%
tfidf_tr
# Out:
# <66863x75 sparse matrix of type '<class 'numpy.float64'>'
# 	with 241615 stored elements in Compressed Sparse Row format>

# %%
tr.to_pickle('./Data/best_set_tr_val')
te.to_pickle('./Data/best_set_te_val')

# %%
tr = pd.read_pickle('./Data/best_set_tr_val')
te = pd.read_pickle('./Data/best_set_te_val')

# %% [markdown]
# # XGBoost

# %%
import xgboost as xgb
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le_types = LabelEncoder()
le_types.fit(tr['TripType'].append(te['TripType']))
tr.loc[:, 'TripType'] = le_types.transform(tr['TripType'])
te.loc[:, 'TripType'] = le_types.transform(te['TripType'])

# %%
params = {"objective": "multi:softprob", 
          "eta": 0.06,
          "max_depth": 6,
          "subsample": 0.65,
          "colsample_bytree": 0.7,
          "silent": 1,
          'min_child_weight': 4,
          'num_class':38,
          'eval_metric': 'mlogloss',
          'nthread':3,
          'seed':7742
          }
# params = {"objective": "multi:softprob", 
#          "eta": 0.075,
#          "max_depth": 25,
#          "subsample": 0.65,
#          "colsample_bytree": 0.7,
#          "silent": 1,
#          'min_child_weight': 4,
#          'num_class':38,
#          'eval_metric': 'mlogloss',
#          'nthread':3,
#          'gamma':2
#          }
ntrees = 400

# %%
cols = list(te.iloc[:, 15:-151].columns)
# cols.remove('TripType')
tr.loc[:, cols] = tr.loc[:, cols].astype(bool).astype(np.int8)
te.loc[:, cols] = te.loc[:, cols].astype(bool).astype(np.int8)

# %%
# Если нужно убрать какую-то группу колонок
cols = list(tr.columns)
l = list()
for i in cols:
    if 'distance' in i:
        l.append(i)

# %%
dtrain = xgb.DMatrix(tr.drop(labels = ['TripType', 'VisitNumber'], axis = 1), label = tr['TripType'])
dvalid = xgb.DMatrix(te.drop(labels = ['TripType', 'VisitNumber'], axis = 1), label = te['TripType'])
# dtest = xgb.DMatrix(te.drop(labels = ['VisitNumber'], axis = 1))
watchlist = [(dvalid, 'eval'), (dtrain, 'train')]

# %%
# %%time
clf = xgb.train(params, 
              dtrain, 
                ntrees, 
                evals=watchlist
               )
# Out:
# [0]	eval-mlogloss:2.999000	train-mlogloss:2.992153
# [1]	eval-mlogloss:2.701854	train-mlogloss:2.689327
# [2]	eval-mlogloss:2.482360	train-mlogloss:2.463699
# [3]	eval-mlogloss:2.312747	train-mlogloss:2.288756
# [4]	eval-mlogloss:2.173299	train-mlogloss:2.144017
# [5]	eval-mlogloss:2.055804	train-mlogloss:2.021454
# [6]	eval-mlogloss:1.952637	train-mlogloss:1.913763
# [7]	eval-mlogloss:1.861657	train-mlogloss:1.818047
# [8]	eval-mlogloss:1.781035	train-mlogloss:1.733462
# [9]	eval-mlogloss:1.707933	train-mlogloss:1.656806
# [10]	eval-mlogloss:1.641513	train-mlogloss:1.586997
# [11]	eval-mlogloss:1.580833	train-mlogloss:1.523162
# [12]	eval-mlogloss:1.525901	train-mlogloss:1.464619
# [13]	eval-mlogloss:1.475739	train-mlogloss:1.411116
# [14]	eval-mlogloss:1.429320	train-mlogloss:1.361097
# [15]	eval-mlogloss:1.385964	train-mlogloss:1.314663
# [16]	eval-mlogloss:1.345923	train-mlogloss:1.271692
# [17]	eval-mlogloss:1.307962	train-mlogloss:1.230779
# [18]	eval-mlogloss:1.272931	train-mlogloss:1.193126
# [19]	eval-mlogloss:1.240448	train-mlogloss:1.157889
# [20]	eval-mlogloss:1.209806	train-mlogloss:1.124601
# [21]	eval-mlogloss:1.180689	train-mlogloss:1.092929
# [22]	eval-mlogloss:1.153426	train-mlogloss:1.063407
# [23]	eval-mlogloss:1.128046	train-mlogloss:1.035690
# [24]	eval-mlogloss:1.104079	train-mlogloss:1.009448
# [25]	eval-mlogloss:1.081544	train-mlogloss:0.984564
# [26]	eval-mlogloss:1.060530	train-mlogloss:0.961148
# [27]	eval-mlogloss:1.040341	train-mlogloss:0.938734
# [28]	eval-mlogloss:1.021364	train-mlogloss:0.917498
# [29]	eval-mlogloss:1.003659	train-mlogloss:0.897564
# [30]	eval-mlogloss:0.986557	train-mlogloss:0.878612
# [31]	eval-mlogloss:0.970446	train-mlogloss:0.860523
# [32]	eval-mlogloss:0.955347	train-mlogloss:0.843308
# [33]	eval-mlogloss:0.941030	train-mlogloss:0.826889
# [34]	eval-mlogloss:0.927411	train-mlogloss:0.810965
# [35]	eval-mlogloss:0.914197	train-mlogloss:0.795828
# [36]	eval-mlogloss:0.901823	train-mlogloss:0.781400
# [37]	eval-mlogloss:0.890182	train-mlogloss:0.767866
# [38]	eval-mlogloss:0.879197	train-mlogloss:0.755029
# [39]	eval-mlogloss:0.868577	train-mlogloss:0.742576
# [40]	eval-mlogloss:0.858537	train-mlogloss:0.730747
# [41]	eval-mlogloss:0.848933	train-mlogloss:0.719327
# [42]	eval-mlogloss:0.839922	train-mlogloss:0.708404
# [43]	eval-mlogloss:0.831180	train-mlogloss:0.697816
# [44]	eval-mlogloss:0.822877	train-mlogloss:0.687808
# [45]	eval-mlogloss:0.814972	train-mlogloss:0.678237
# [46]	eval-mlogloss:0.807519	train-mlogloss:0.669054
# [47]	eval-mlogloss:0.800359	train-mlogloss:0.660181
# [48]	eval-mlogloss:0.793411	train-mlogloss:0.651425
# [49]	eval-mlogloss:0.786736	train-mlogloss:0.643052
# [50]	eval-mlogloss:0.780528	train-mlogloss:0.634967
# [51]	eval-mlogloss:0.774554	train-mlogloss:0.627280
# [52]	eval-mlogloss:0.768716	train-mlogloss:0.619675
# [53]	eval-mlogloss:0.763430	train-mlogloss:0.612422
# [54]	eval-mlogloss:0.758051	train-mlogloss:0.605305
# [55]	eval-mlogloss:0.752987	train-mlogloss:0.598399
# [56]	eval-mlogloss:0.748100	train-mlogloss:0.592069
# [57]	eval-mlogloss:0.743326	train-mlogloss:0.585813
# [58]	eval-mlogloss:0.739003	train-mlogloss:0.579816
# [59]	eval-mlogloss:0.734742	train-mlogloss:0.573913
# [60]	eval-mlogloss:0.730726	train-mlogloss:0.568382
# [61]	eval-mlogloss:0.726771	train-mlogloss:0.562912
# [62]	eval-mlogloss:0.723015	train-mlogloss:0.557550
# [63]	eval-mlogloss:0.719410	train-mlogloss:0.552504
# [64]	eval-mlogloss:0.716078	train-mlogloss:0.547647
# [65]	eval-mlogloss:0.712654	train-mlogloss:0.542789
# [66]	eval-mlogloss:0.709450	train-mlogloss:0.538244
# [67]	eval-mlogloss:0.706362	train-mlogloss:0.533714
# [68]	eval-mlogloss:0.703544	train-mlogloss:0.529365
# [69]	eval-mlogloss:0.700632	train-mlogloss:0.525310
# [70]	eval-mlogloss:0.697861	train-mlogloss:0.521179
# [71]	eval-mlogloss:0.695279	train-mlogloss:0.517240
# [72]	eval-mlogloss:0.692734	train-mlogloss:0.513196
# [73]	eval-mlogloss:0.690334	train-mlogloss:0.509322
# [74]	eval-mlogloss:0.687935	train-mlogloss:0.505453
# [75]	eval-mlogloss:0.685541	train-mlogloss:0.501817
# [76]	eval-mlogloss:0.683327	train-mlogloss:0.498321
# [77]	eval-mlogloss:0.681110	train-mlogloss:0.494745
# [78]	eval-mlogloss:0.679027	train-mlogloss:0.491354
# [79]	eval-mlogloss:0.677001	train-mlogloss:0.488125
# [80]	eval-mlogloss:0.675103	train-mlogloss:0.484867
# [81]	eval-mlogloss:0.673168	train-mlogloss:0.481500
# [82]	eval-mlogloss:0.671325	train-mlogloss:0.478346
# [83]	eval-mlogloss:0.669671	train-mlogloss:0.475282
# [84]	eval-mlogloss:0.668042	train-mlogloss:0.472458
# [85]	eval-mlogloss:0.666445	train-mlogloss:0.469530
# [86]	eval-mlogloss:0.664915	train-mlogloss:0.466707
# [87]	eval-mlogloss:0.663447	train-mlogloss:0.463877
# [88]	eval-mlogloss:0.662023	train-mlogloss:0.461278
# [89]	eval-mlogloss:0.660643	train-mlogloss:0.458689
# [90]	eval-mlogloss:0.659246	train-mlogloss:0.455988
# [91]	eval-mlogloss:0.657843	train-mlogloss:0.453329
# [92]	eval-mlogloss:0.656655	train-mlogloss:0.450922
# [93]	eval-mlogloss:0.655525	train-mlogloss:0.448511
# [94]	eval-mlogloss:0.654383	train-mlogloss:0.446205
# [95]	eval-mlogloss:0.653211	train-mlogloss:0.443774
# [96]	eval-mlogloss:0.652077	train-mlogloss:0.441466
# [97]	eval-mlogloss:0.650944	train-mlogloss:0.439081
# [98]	eval-mlogloss:0.649936	train-mlogloss:0.436780
# [99]	eval-mlogloss:0.648930	train-mlogloss:0.434496
# [100]	eval-mlogloss:0.647852	train-mlogloss:0.432276
# [101]	eval-mlogloss:0.646907	train-mlogloss:0.430018
# [102]	eval-mlogloss:0.645821	train-mlogloss:0.427825
# [103]	eval-mlogloss:0.644949	train-mlogloss:0.425841
# [104]	eval-mlogloss:0.644089	train-mlogloss:0.423774
# [105]	eval-mlogloss:0.643180	train-mlogloss:0.421719
# [106]	eval-mlogloss:0.642366	train-mlogloss:0.419639
# [107]	eval-mlogloss:0.641658	train-mlogloss:0.417626
# [108]	eval-mlogloss:0.640871	train-mlogloss:0.415694
# [109]	eval-mlogloss:0.640082	train-mlogloss:0.413727
# [110]	eval-mlogloss:0.639330	train-mlogloss:0.411909
# [111]	eval-mlogloss:0.638606	train-mlogloss:0.410076
# [112]	eval-mlogloss:0.637877	train-mlogloss:0.408250
# [113]	eval-mlogloss:0.637224	train-mlogloss:0.406287
# [114]	eval-mlogloss:0.636581	train-mlogloss:0.404384
# [115]	eval-mlogloss:0.635896	train-mlogloss:0.402523
# [116]	eval-mlogloss:0.635122	train-mlogloss:0.400568
# [117]	eval-mlogloss:0.634503	train-mlogloss:0.398887
# [118]	eval-mlogloss:0.633906	train-mlogloss:0.397131
# [119]	eval-mlogloss:0.633337	train-mlogloss:0.395353
# [120]	eval-mlogloss:0.632765	train-mlogloss:0.393679
# [121]	eval-mlogloss:0.632163	train-mlogloss:0.392064
# [122]	eval-mlogloss:0.631519	train-mlogloss:0.390438
# [123]	eval-mlogloss:0.630976	train-mlogloss:0.388783
# [124]	eval-mlogloss:0.630428	train-mlogloss:0.387355
# [125]	eval-mlogloss:0.629892	train-mlogloss:0.385647
# [126]	eval-mlogloss:0.629447	train-mlogloss:0.384046
# [127]	eval-mlogloss:0.628867	train-mlogloss:0.382544
# [128]	eval-mlogloss:0.628444	train-mlogloss:0.381052
# [129]	eval-mlogloss:0.628008	train-mlogloss:0.379562
# [130]	eval-mlogloss:0.627457	train-mlogloss:0.378132
# [131]	eval-mlogloss:0.627098	train-mlogloss:0.376667
# [132]	eval-mlogloss:0.626744	train-mlogloss:0.375202
# [133]	eval-mlogloss:0.626266	train-mlogloss:0.373661
# [134]	eval-mlogloss:0.625858	train-mlogloss:0.372296
# [135]	eval-mlogloss:0.625561	train-mlogloss:0.370853
# [279]	eval-mlogloss:0.608485	train-mlogloss:0.234582
# [280]	eval-mlogloss:0.608461	train-mlogloss:0.233873
# [281]	eval-mlogloss:0.608415	train-mlogloss:0.233195
# [282]	eval-mlogloss:0.608434	train-mlogloss:0.232501
# [283]	eval-mlogloss:0.608468	train-mlogloss:0.231913
# [284]	eval-mlogloss:0.608475	train-mlogloss:0.231220
# [285]	eval-mlogloss:0.608438	train-mlogloss:0.230618
# [286]	eval-mlogloss:0.608398	train-mlogloss:0.229951
# [287]	eval-mlogloss:0.608356	train-mlogloss:0.229282
# [288]	eval-mlogloss:0.608351	train-mlogloss:0.228605
# [289]	eval-mlogloss:0.608400	train-mlogloss:0.228058
# [290]	eval-mlogloss:0.608401	train-mlogloss:0.227371
# [291]	eval-mlogloss:0.608402	train-mlogloss:0.226681
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-54-99373162be9d> in <module>()
# ----> 1 get_ipython().run_cell_magic('time', '', 'clf = xgb.train(params, \n              dtrain, \n                ntrees, \n                evals=watchlist\n               )')
#
# /opt/conda/Anaconda3/lib/python3.4/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2291             magic_arg_s = self.var_expand(line, stack_depth)
#    2292             with self.builtin_trap:
# -> 2293                 result = fn(magic_arg_s, cell)
#    2294             return result
#    2295
#
# /opt/conda/Anaconda3/lib/python3.4/site-packages/IPython/core/magics/execution.py in time(self, line, cell, local_ns)
#
# /opt/conda/Anaconda3/lib/python3.4/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# /opt/conda/Anaconda3/lib/python3.4/site-packages/IPython/core/magics/execution.py in time(self, line, cell, local_ns)
#    1165         else:
#    1166             st = clock2()
# -> 1167             exec(code, glob, local_ns)
#    1168             end = clock2()
#    1169             out = None
#
# <timed exec> in <module>()
#
# /opt/conda/Anaconda3/lib/python3.4/site-packages/xgboost-0.4-py3.4.egg/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, early_stopping_rounds, evals_result, verbose_eval)
#      60     if not early_stopping_rounds:
#      61         for i in range(num_boost_round):
# ---> 62             bst.update(dtrain, i, obj)
#      63             if len(evals) != 0:
#      64                 bst_eval_set = bst.eval_set(evals, i, feval)
#
# /opt/conda/Anaconda3/lib/python3.4/site-packages/xgboost-0.4-py3.4.egg/xgboost/core.py in update(self, dtrain, iteration, fobj)
#     521             raise TypeError('invalid training matrix: {}'.format(type(dtrain).__name__))
#     522         if fobj is None:
# --> 523             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle, iteration, dtrain.handle))
#     524         else:
#     525             pred = self.predict(dtrain)
#
# KeyboardInterrupt:

# %%
# %%time
clf = xgb.train(params, 
              dtrain, 
                ntrees, 
                evals=watchlist
               )
# Out:
# [0]	eval-mlogloss:3.030509	train-mlogloss:3.024972
# [1]	eval-mlogloss:2.730874	train-mlogloss:2.719553
# [2]	eval-mlogloss:2.516286	train-mlogloss:2.500377
# [3]	eval-mlogloss:2.346014	train-mlogloss:2.325711
# [4]	eval-mlogloss:2.206857	train-mlogloss:2.182132
# [5]	eval-mlogloss:2.087810	train-mlogloss:2.058952
# [6]	eval-mlogloss:1.985061	train-mlogloss:1.952034
# [7]	eval-mlogloss:1.894121	train-mlogloss:1.857082
# [8]	eval-mlogloss:1.813966	train-mlogloss:1.773118
# [9]	eval-mlogloss:1.740405	train-mlogloss:1.696429
# [10]	eval-mlogloss:1.673870	train-mlogloss:1.626688
# [11]	eval-mlogloss:1.613930	train-mlogloss:1.563565
# [12]	eval-mlogloss:1.559393	train-mlogloss:1.505850
# [13]	eval-mlogloss:1.509342	train-mlogloss:1.452861
# [14]	eval-mlogloss:1.461850	train-mlogloss:1.402655
# [15]	eval-mlogloss:1.418507	train-mlogloss:1.356642
# [16]	eval-mlogloss:1.377622	train-mlogloss:1.312964
# [17]	eval-mlogloss:1.339624	train-mlogloss:1.272480
# [18]	eval-mlogloss:1.303764	train-mlogloss:1.234089
# [19]	eval-mlogloss:1.271065	train-mlogloss:1.198848
# [20]	eval-mlogloss:1.240262	train-mlogloss:1.165808
# [21]	eval-mlogloss:1.211332	train-mlogloss:1.134640
# [22]	eval-mlogloss:1.184315	train-mlogloss:1.105377
# [23]	eval-mlogloss:1.158951	train-mlogloss:1.077693
# [24]	eval-mlogloss:1.134516	train-mlogloss:1.050942
# [25]	eval-mlogloss:1.111735	train-mlogloss:1.025803
# [26]	eval-mlogloss:1.090042	train-mlogloss:1.001901
# [27]	eval-mlogloss:1.070082	train-mlogloss:0.979981
# [28]	eval-mlogloss:1.050844	train-mlogloss:0.958596
# [29]	eval-mlogloss:1.032631	train-mlogloss:0.938215
# [30]	eval-mlogloss:1.015289	train-mlogloss:0.918526
# [31]	eval-mlogloss:0.998997	train-mlogloss:0.900309
# [32]	eval-mlogloss:0.982915	train-mlogloss:0.882368
# [33]	eval-mlogloss:0.968438	train-mlogloss:0.865977
# [34]	eval-mlogloss:0.954373	train-mlogloss:0.849871
# [35]	eval-mlogloss:0.941143	train-mlogloss:0.834595
# [36]	eval-mlogloss:0.928230	train-mlogloss:0.819620
# [37]	eval-mlogloss:0.916085	train-mlogloss:0.805769
# [38]	eval-mlogloss:0.904429	train-mlogloss:0.792317
# [39]	eval-mlogloss:0.893365	train-mlogloss:0.779467
# [40]	eval-mlogloss:0.882874	train-mlogloss:0.767143
# [41]	eval-mlogloss:0.872969	train-mlogloss:0.755643
# [42]	eval-mlogloss:0.863490	train-mlogloss:0.744507
# [43]	eval-mlogloss:0.854375	train-mlogloss:0.733647
# [44]	eval-mlogloss:0.846080	train-mlogloss:0.723660
# [45]	eval-mlogloss:0.837805	train-mlogloss:0.713579
# [46]	eval-mlogloss:0.830223	train-mlogloss:0.704108
# [47]	eval-mlogloss:0.822865	train-mlogloss:0.694905
# [48]	eval-mlogloss:0.815699	train-mlogloss:0.686101
# [49]	eval-mlogloss:0.808753	train-mlogloss:0.677576
# [50]	eval-mlogloss:0.802080	train-mlogloss:0.669382
# [51]	eval-mlogloss:0.795846	train-mlogloss:0.661438
# [52]	eval-mlogloss:0.789927	train-mlogloss:0.653897
# [53]	eval-mlogloss:0.784239	train-mlogloss:0.646634
# [54]	eval-mlogloss:0.778771	train-mlogloss:0.639570
# [55]	eval-mlogloss:0.773530	train-mlogloss:0.632565
# [56]	eval-mlogloss:0.768363	train-mlogloss:0.626018
# [57]	eval-mlogloss:0.763497	train-mlogloss:0.619643
# [58]	eval-mlogloss:0.758937	train-mlogloss:0.613374
# [59]	eval-mlogloss:0.754592	train-mlogloss:0.607340
# [60]	eval-mlogloss:0.750353	train-mlogloss:0.601474
# [61]	eval-mlogloss:0.746380	train-mlogloss:0.596014
# [62]	eval-mlogloss:0.742535	train-mlogloss:0.590600
# [63]	eval-mlogloss:0.738649	train-mlogloss:0.585225
# [64]	eval-mlogloss:0.734949	train-mlogloss:0.580082
# [65]	eval-mlogloss:0.731603	train-mlogloss:0.575257
# [66]	eval-mlogloss:0.728243	train-mlogloss:0.570556
# [67]	eval-mlogloss:0.724880	train-mlogloss:0.565701
# [68]	eval-mlogloss:0.721888	train-mlogloss:0.561312
# [69]	eval-mlogloss:0.718896	train-mlogloss:0.556982
# [70]	eval-mlogloss:0.716021	train-mlogloss:0.552678
# [71]	eval-mlogloss:0.713054	train-mlogloss:0.548347
# [72]	eval-mlogloss:0.710411	train-mlogloss:0.544409
# [73]	eval-mlogloss:0.707825	train-mlogloss:0.540587
# [74]	eval-mlogloss:0.705343	train-mlogloss:0.536865
# [75]	eval-mlogloss:0.702857	train-mlogloss:0.533143
# [76]	eval-mlogloss:0.700689	train-mlogloss:0.529648
# [77]	eval-mlogloss:0.698561	train-mlogloss:0.526235
# [78]	eval-mlogloss:0.696491	train-mlogloss:0.522947
# [79]	eval-mlogloss:0.694217	train-mlogloss:0.519474
# [80]	eval-mlogloss:0.692321	train-mlogloss:0.516178
# [81]	eval-mlogloss:0.690328	train-mlogloss:0.512761
# [82]	eval-mlogloss:0.688369	train-mlogloss:0.509654
# [83]	eval-mlogloss:0.686483	train-mlogloss:0.506447
# [84]	eval-mlogloss:0.684656	train-mlogloss:0.503428
# [85]	eval-mlogloss:0.682961	train-mlogloss:0.500409
# [86]	eval-mlogloss:0.681400	train-mlogloss:0.497600
# [87]	eval-mlogloss:0.679798	train-mlogloss:0.494864
# [88]	eval-mlogloss:0.678056	train-mlogloss:0.491878
# [89]	eval-mlogloss:0.676439	train-mlogloss:0.489010
# [90]	eval-mlogloss:0.674884	train-mlogloss:0.486374
# [91]	eval-mlogloss:0.673419	train-mlogloss:0.483663
# [92]	eval-mlogloss:0.671905	train-mlogloss:0.480963
# [93]	eval-mlogloss:0.670610	train-mlogloss:0.478635
# [94]	eval-mlogloss:0.669262	train-mlogloss:0.476132
# [95]	eval-mlogloss:0.668040	train-mlogloss:0.473720
# [96]	eval-mlogloss:0.666812	train-mlogloss:0.471353
# [97]	eval-mlogloss:0.665640	train-mlogloss:0.468967
# [98]	eval-mlogloss:0.664426	train-mlogloss:0.466692
# [99]	eval-mlogloss:0.663285	train-mlogloss:0.464319
# [100]	eval-mlogloss:0.662312	train-mlogloss:0.462243
# [101]	eval-mlogloss:0.661205	train-mlogloss:0.460146
# [102]	eval-mlogloss:0.660164	train-mlogloss:0.458145
# [103]	eval-mlogloss:0.659254	train-mlogloss:0.456010
# [104]	eval-mlogloss:0.658282	train-mlogloss:0.454002
# [105]	eval-mlogloss:0.657211	train-mlogloss:0.451968
# [106]	eval-mlogloss:0.656394	train-mlogloss:0.450095
# [107]	eval-mlogloss:0.655482	train-mlogloss:0.448209
# [108]	eval-mlogloss:0.654650	train-mlogloss:0.446279
# [109]	eval-mlogloss:0.653912	train-mlogloss:0.444480
# [110]	eval-mlogloss:0.653203	train-mlogloss:0.442723
# [111]	eval-mlogloss:0.652395	train-mlogloss:0.440964
# [112]	eval-mlogloss:0.651605	train-mlogloss:0.439167
# [113]	eval-mlogloss:0.650876	train-mlogloss:0.437391
# [114]	eval-mlogloss:0.650153	train-mlogloss:0.435643
# [115]	eval-mlogloss:0.649604	train-mlogloss:0.434135
# [116]	eval-mlogloss:0.648830	train-mlogloss:0.432553
# [356]	eval-mlogloss:0.614938	train-mlogloss:0.260390
# [357]	eval-mlogloss:0.614896	train-mlogloss:0.259939
# [358]	eval-mlogloss:0.614895	train-mlogloss:0.259540
# [359]	eval-mlogloss:0.614916	train-mlogloss:0.259123
# [360]	eval-mlogloss:0.614912	train-mlogloss:0.258711
# [361]	eval-mlogloss:0.614944	train-mlogloss:0.258317
# [362]	eval-mlogloss:0.614979	train-mlogloss:0.257898
# [363]	eval-mlogloss:0.615022	train-mlogloss:0.257500
# [364]	eval-mlogloss:0.615018	train-mlogloss:0.257077
# [365]	eval-mlogloss:0.615028	train-mlogloss:0.256630
# [366]	eval-mlogloss:0.615006	train-mlogloss:0.256205
# [367]	eval-mlogloss:0.614942	train-mlogloss:0.255856
# [368]	eval-mlogloss:0.614947	train-mlogloss:0.255504
# [369]	eval-mlogloss:0.615000	train-mlogloss:0.255165
# [370]	eval-mlogloss:0.615030	train-mlogloss:0.254781
# [371]	eval-mlogloss:0.615021	train-mlogloss:0.254386
# [372]	eval-mlogloss:0.615020	train-mlogloss:0.253988
# [373]	eval-mlogloss:0.615046	train-mlogloss:0.253616
# [374]	eval-mlogloss:0.615067	train-mlogloss:0.253250
# [375]	eval-mlogloss:0.615022	train-mlogloss:0.252858
# [376]	eval-mlogloss:0.615032	train-mlogloss:0.252439
# [377]	eval-mlogloss:0.615013	train-mlogloss:0.252074
# [378]	eval-mlogloss:0.615024	train-mlogloss:0.251717
# [379]	eval-mlogloss:0.615009	train-mlogloss:0.251357
# [380]	eval-mlogloss:0.615016	train-mlogloss:0.251007
# [381]	eval-mlogloss:0.615012	train-mlogloss:0.250670
# [382]	eval-mlogloss:0.615049	train-mlogloss:0.250309
# [383]	eval-mlogloss:0.615088	train-mlogloss:0.249976
# [384]	eval-mlogloss:0.615073	train-mlogloss:0.249647
# [385]	eval-mlogloss:0.615024	train-mlogloss:0.249204
# [386]	eval-mlogloss:0.615044	train-mlogloss:0.248827
# [387]	eval-mlogloss:0.615069	train-mlogloss:0.248457
# [388]	eval-mlogloss:0.615055	train-mlogloss:0.248082
# [389]	eval-mlogloss:0.615089	train-mlogloss:0.247720
# [390]	eval-mlogloss:0.615047	train-mlogloss:0.247309
# [391]	eval-mlogloss:0.614968	train-mlogloss:0.246865
# [392]	eval-mlogloss:0.614979	train-mlogloss:0.246527
# [393]	eval-mlogloss:0.615034	train-mlogloss:0.246214
# [394]	eval-mlogloss:0.615036	train-mlogloss:0.245831
# [395]	eval-mlogloss:0.615047	train-mlogloss:0.245411
# [396]	eval-mlogloss:0.615048	train-mlogloss:0.245024
# [397]	eval-mlogloss:0.615016	train-mlogloss:0.244628
# [398]	eval-mlogloss:0.615003	train-mlogloss:0.244231
# [399]	eval-mlogloss:0.614965	train-mlogloss:0.243756
# CPU times: user 3h 57min 51s, sys: 1.83 s, total: 3h 57min 53s
# Wall time: 1h 25min 53s

# %%
ave = pred.copy()

# %%
from sklearn.metrics import log_loss
# ave = True
for i in range(4):
    params = {"objective": "multi:softprob", 
              "eta": 0.06,
              "max_depth": 6,
              "subsample": 0.65,
              "colsample_bytree": 0.7,
              "silent": 1,
              'min_child_weight': 4,
              'num_class':38,
              'eval_metric': 'mlogloss',
              'nthread':3,
              'seed':7742
              }
    clf = xgb.train(params, 
                    dtrain, 
                    ntrees, 
#                     evals=watchlist
                   )
    pred = clf.predict(dtest)
#     pred_train = clf.predict(dtrain)
    if type(ave) == bool:
        ave = pred.copy()
    else:
        ave += pred
#     print('Validation loss: {0}, train loss: {1}'.format(log_loss(te['TripType'], pred), log_loss(tr['TripType'], pred_train)))
# print('Average prediction loss {0}'.format(log_loss(te['TripType'], ave/15.)))

# %%
from sklearn.metrics import log_loss
print('Validation loss: {0}, train loss: {1}'.format(log_loss(te['TripType'], pred), log_loss(tr['TripType'], pred_train)))
# Out:
# Validation loss: 0.7428016404853823, train loss: 0.31202338004996805

# %%
eval-mlogloss:0.775806	train-mlogloss:0.349957

# %%
pred = clf.predict(dtrain)

# %%
from sklearn.metrics import log_loss
# log_loss(tr['TripType'], pred)

# %%
pred = clf.predict(dvalid)
log_loss(te['TripType'], pred)
# Out:
# 0.83126021368876035

# %% [markdown]
# # RF attempt

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=400, 
                             criterion='gini', 
                             max_depth=5, 
                             min_samples_split=2, 
                             min_samples_leaf=10, 
                             min_weight_fraction_leaf=0.0, 
                             max_features=0.5, 
                             max_leaf_nodes=None, 
                             bootstrap=True, 
                             oob_score=False, 
                             n_jobs=-1, 
                             random_state=4222, 
                             verbose=0, 
                             warm_start=False, 
                             class_weight=None)

# %%
rf.fit(tr.drop(labels = ['TripType', 'VisitNumber'], axis = 1), tr['TripType'])
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features=0.5, max_leaf_nodes=None,
#             min_samples_leaf=10, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=400, n_jobs=-1,
#             oob_score=False, random_state=4222, verbose=0,
#             warm_start=False)

# %%
pred = rf.predict_proba(te.drop(labels = ['TripType', 'VisitNumber'], axis = 1))
print(log_loss(te['TripType'], pred))
pred = rf.predict_proba(tr.drop(labels = ['TripType', 'VisitNumber'], axis = 1))
print(log_loss(tr['TripType'], pred))
# Out:
# 1.83551292437
# 1.81207197284

# %%
features = list(te.drop(labels = ['TripType', 'VisitNumber'], axis = 1).columns)

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline

importances = rf.feature_importances_
std = np.std([tree.feature_importances_ for tree in rf.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1]

# Print the feature ranking
print("Feature ranking:")

for f in range(len(features)):
    print("%d. feature %d (%f)" % (f + 1, indices[f], importances[indices[f]]), features[indices[f]])

# Plot the feature importances of the forest
plt.figure()
plt.title("Feature importances")
plt.bar(range(len(features)), importances[indices],
       color="r", yerr=std[indices], align="center")
plt.xticks(range(len(features)), indices)
plt.xlim([-1, len(features)])
plt.show()
# Out:
# Feature ranking:
# 1. feature 6 (0.194367) num_goods
# 2. feature 12 (0.084889) return_dummy
# 3. feature 8 (0.079349) num_positions
# 4. feature 2500 (0.074239) KNN_5
# 5. feature 10 (0.073461) num_returns
# 6. feature 507 (0.042785) DepartmentDescription_0_FINANCIAL SERVICES
# 7. feature 2462 (0.042460) Ridge_8
# 8. feature 2461 (0.040791) Ridge_7
# 9. feature 2474 (0.038230) Ridge_25
# 10. feature 5 (0.035378) num_fineline
# 11. feature 2457 (0.034890) Ridge_3
# 12. feature 2494 (0.025571) Ridge_999
# 13. feature 2424 (0.021711) FinelineNumber_distance_to_8
# 14. feature 3 (0.020912) num_cats
# 15. feature 7 (0.018500) num_ones
# 16. feature 2485 (0.017176) Ridge_36
# 17. feature 2495 (0.015621) KNN_0
# 18. feature 2489 (0.015244) Ridge_40
# 19. feature 2487 (0.014297) Ridge_38
# 20. feature 2499 (0.013476) KNN_4
# 21. feature 2486 (0.012042) Ridge_37
# 22. feature 2463 (0.007541) Ridge_9
# 23. feature 2419 (0.006914) FinelineNumber_distance_to_3
# 24. feature 2423 (0.005785) FinelineNumber_distance_to_7
# 25. feature 2532 (0.004961) KNN_37
# 26. feature 534 (0.004896) DepartmentDescription_1_PHARMACY RX
# 27. feature 1 (0.004709) max_scans
# 28. feature 13 (0.004629) ave_position
# 29. feature 2488 (0.004258) Ridge_39
# 30. feature 510 (0.003256) DepartmentDescription_0_GROCERY DRY GOODS
# 31. feature 545 (0.003253) FinelineNumber_0_0.0
# 32. feature 9 (0.002706) num_rare_goods
# 33. feature 2501 (0.002673) KNN_6
# 34. feature 539 (0.002244) DepartmentDescription_0_SERVICE DELI
# 35. feature 1305 (0.001969) 2Upc_2_60538809877.060538819035.0
# 36. feature 320 (0.001819) Upc_8_60538809877.0
# 37. feature 0 (0.001605) all_return
# 38. feature 4 (0.001464) num_diff_q
# 39. feature 2456 (0.001405) FinelineNumber_distance_to_999
# 40. feature 2436 (0.001316) FinelineNumber_distance_to_25
# 41. feature 2491 (0.001304) Ridge_42
# 42. feature 2512 (0.001208) KNN_17
# 43. feature 2182 (0.001133) 2DepartmentDescription_0_DSD GROCERYGROCERY DRY GOODS
# 44. feature 531 (0.001095) DepartmentDescription_0_PERSONAL CARE
# 45. feature 519 (0.001057) DepartmentDescription_0_INFANT CONSUMABLE HARDLINES
# 46. feature 527 (0.001002) DepartmentDescription_0_MENS WEAR
# 47. feature 2481 (0.000969) Ridge_32
# 48. feature 533 (0.000943) DepartmentDescription_0_PHARMACY OTC
# 49. feature 537 (0.000920) DepartmentDescription_0_PRODUCE
# 50. feature 2484 (0.000608) Ridge_35
# 51. feature 2446 (0.000565) FinelineNumber_distance_to_35
# 52. feature 2160 (0.000505) 2DepartmentDescription_0_DAIRYGROCERY DRY GOODS
# 53. feature 2447 (0.000488) FinelineNumber_distance_to_36
# 54. feature 2473 (0.000450) Ridge_24
# 55. feature 2449 (0.000403) FinelineNumber_distance_to_38
# 56. feature 383 (0.000360) Upc_10_68113174202.0
# 57. feature 2451 (0.000350) FinelineNumber_distance_to_40
# 58. feature 2482 (0.000265) Ridge_33
# 59. feature 2455 (0.000262) FinelineNumber_distance_to_44
# 60. feature 2156 (0.000249) 2DepartmentDescription_1_DAIRYDSD GROCERY
# 61. feature 504 (0.000218) DepartmentDescription_0_DSD GROCERY
# 62. feature 2425 (0.000179) FinelineNumber_distance_to_9
# 63. feature 2448 (0.000157) FinelineNumber_distance_to_37
# 64. feature 2493 (0.000130) Ridge_44
# 65. feature 499 (0.000125) DepartmentDescription_1_CANDY, TOBACCO, COOKIES
# 66. feature 2443 (0.000117) FinelineNumber_distance_to_32
# 67. feature 503 (0.000108) DepartmentDescription_0_DAIRY
# 2521. feature 1602 (0.000000) 2FinelineNumber_16_1201.05501.0
# 2522. feature 1601 (0.000000) 2FinelineNumber_7_1200.0900.0
# 2523. feature 1600 (0.000000) 2FinelineNumber_9_1200.01224.0
# 2524. feature 1599 (0.000000) 2FinelineNumber_12_1168.03903.0
# 2525. feature 1597 (0.000000) 2FinelineNumber_17_1165.01190.0
# 2526. feature 1590 (0.000000) 2FinelineNumber_5_115.08012.0
# 2527. feature 1596 (0.000000) 2FinelineNumber_15_1162.03903.0
# 2528. feature 1595 (0.000000) 2FinelineNumber_18_1156.05501.0
# 2529. feature 1594 (0.000000) 2FinelineNumber_4_1156.02042.0
# 2530. feature 1593 (0.000000) 2FinelineNumber_5_1153.03903.0
# 2531. feature 1592 (0.000000) 2FinelineNumber_4_115.09546.0
# 2532. feature 1591 (0.000000) 2FinelineNumber_1_115.0808.0
# 2533. feature 1266 (0.000000) 2Upc_18_5000058508.05000058512.0

# %% [markdown]
# # XGBoost Feature Importance

# %%
# %matplotlib inline

# %%
features = tr.drop(labels = ['TripType', 'VisitNumber'], axis = 1).columns
mapFeat = dict(zip(["f"+str(i) for i in range(len(features))],features))
ts = pd.Series(clf.get_fscore())
ts.index = ts.reset_index()['index'].map(mapFeat)
ts.sort_values()[-75:].plot(kind="barh", title=("features importance"), figsize = (10,20))
# Out:
# /opt/conda/Anaconda3/lib/python3.4/site-packages/ipykernel/__main__.py:5: FutureWarning: order is deprecated, use sort_values(...)

# %% [markdown]
# # Create file for Kaggle

# %%
pred = clf.predict(dtest)
pred_df = pd.DataFrame(pred, columns = ['TripType_' + str(i) for i in le_types.inverse_transform(np.arange(38))])
pred_df.insert(0, 'VisitNumber', te.VisitNumber)
pred_df.to_csv('./Submissions/XGB_fineline_distances_ridge_4500.csv', index=False)

# %%
pred_df.insert(0, 'VisitNumber', te.VisitNumber)
pred_df.to_csv('./Submissions/XGB_secret_feature_300.csv', index=False)

# %% [markdown]
# # TSNE attempt - FAIL

# %%
from sklearn.manifold import TSNE
import pandas as pd

# %%
features_tr = pd.read_pickle('./Data/tfidif_tr_val')
features_te = pd.read_pickle('./Data/tfidif_te_val')

# %%
proj = TSNE(n_components=2, 
                      perplexity=30.0, 
                      early_exaggeration=4.0, 
                      learning_rate=1000.0, 
                      n_iter=1000, 
                      n_iter_without_progress=30, 
                      min_grad_norm=1e-07, 
                      metric='euclidean', 
                      init='random', 
                      verbose=4, 
                      random_state=77777, 
                      method='barnes_hut', 
                      angle=0.5)

# %%
features_te.drop(labels = ['VisitNumber'], inplace = True, axis = 1)
features_tr.drop(labels = ['VisitNumber'], inplace = True, axis = 1)

# %%
s = proj.fit_transform(features_te.as_matrix())
# Out:
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Computed conditional probabilities for sample 1000 / 18861
# [t-SNE] Computed conditional probabilities for sample 2000 / 18861
# [t-SNE] Computed conditional probabilities for sample 3000 / 18861
# [t-SNE] Computed conditional probabilities for sample 4000 / 18861
# [t-SNE] Computed conditional probabilities for sample 5000 / 18861
# [t-SNE] Computed conditional probabilities for sample 6000 / 18861
# [t-SNE] Computed conditional probabilities for sample 7000 / 18861
# [t-SNE] Computed conditional probabilities for sample 8000 / 18861
# [t-SNE] Computed conditional probabilities for sample 9000 / 18861
# [t-SNE] Computed conditional probabilities for sample 10000 / 18861
# [t-SNE] Computed conditional probabilities for sample 11000 / 18861
# [t-SNE] Computed conditional probabilities for sample 12000 / 18861
# [t-SNE] Computed conditional probabilities for sample 13000 / 18861
# [t-SNE] Computed conditional probabilities for sample 14000 / 18861
# [t-SNE] Computed conditional probabilities for sample 15000 / 18861
# [t-SNE] Computed conditional probabilities for sample 16000 / 18861
# [t-SNE] Computed conditional probabilities for sample 17000 / 18861
# [t-SNE] Computed conditional probabilities for sample 18000 / 18861
# [t-SNE] Computed conditional probabilities for sample 18861 / 18861
# [t-SNE] Mean sigma: 0.000000
# [t-SNE] Iteration 25: error = 0.9376866, gradient norm = 0.0000437
# [t-SNE] Iteration 25: gradient norm 0.000044. Finished.
# [t-SNE] Iteration 50: error = 0.9369927, gradient norm = 0.0055213
# [t-SNE] Iteration 75: error = 0.9333201, gradient norm = 0.0040166
# [t-SNE] Iteration 100: error = 0.9325002, gradient norm = 0.0036716
# [t-SNE] Error after 100 iterations with early exaggeration: 0.932500
# [t-SNE] Iteration 125: error = 0.9262915, gradient norm = 0.0023723
# [t-SNE] Iteration 150: error = 0.9238974, gradient norm = 0.0021758
# [t-SNE] Iteration 175: error = 0.9233110, gradient norm = 0.0021477
# [t-SNE] Iteration 200: error = 0.9231643, gradient norm = 0.0021442
# [t-SNE] Iteration 225: error = 0.9231269, gradient norm = 0.0021432
# [t-SNE] Iteration 250: error = 0.9231156, gradient norm = 0.0021409
# [t-SNE] Iteration 250: error difference 0.000000. Finished.
# [t-SNE] Error after 250 iterations: 0.923116

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
temp_te.reset_index(drop=True, inplace = True)

# %%
qq = [29, 4, 999]
plt.figure(figsize = (15,15))
plt.scatter(s[temp_te[temp_te['TripType'].isin(qq)].index,0], s[temp_te[temp_te['TripType'].isin(qq)].index,1], c=temp_te[temp_te['TripType'].isin(qq)].TripType, alpha=0.5, cmap='jet')
plt.show()

# %%
ave
# Out:
# array([[  3.21547377e-05,   1.82837230e-05,   1.70599742e-04, ...,
#           5.03964955e-03,   9.52632981e-04,   6.22415170e-03],
#        [  6.92203699e-04,   1.09736226e-04,   2.03932310e-03, ...,
#           2.21803799e-01,   3.86935170e-03,   3.30059862e+00],
#        [  1.45022277e-05,   9.07426170e-07,   8.45964765e-04, ...,
#           1.02569684e-05,   4.80538256e-06,   4.98146343e+00],
#        ...,
#        [  4.36743605e-04,   6.94984847e-05,   4.60562151e-04, ...,
#           1.50591630e-04,   1.10465153e-04,   3.21291108e-03],
#        [  4.46512104e-06,   4.07926018e-06,   6.03643311e-05, ...,
#           4.23005261e-02,   7.96580985e-02,   3.67886794e-04],
#        [  2.13155145e-05,   1.50231326e-05,   9.74286231e-05, ...,
#           2.63576861e-02,   7.27874925e-03,   1.69465155e-03]], dtype=float32)

# %%
pred
# Out:
# array([[  6.43094745e-06,   3.65674464e-06,   3.41199484e-05, ...,
#           1.00792991e-03,   1.90526596e-04,   1.24483032e-03],
#        [  1.38440737e-04,   2.19472458e-05,   4.07864602e-04, ...,
#           4.43607606e-02,   7.73870328e-04,   6.60119712e-01],
#        [  2.90044545e-06,   1.81485234e-07,   1.69192950e-04, ...,
#           2.05139372e-06,   9.61076466e-07,   9.96292651e-01],
#        ...,
#        [  8.73487224e-05,   1.38996966e-05,   9.21124301e-05, ...,
#           3.01183263e-05,   2.20930306e-05,   6.42582192e-04],
#        [  8.93024207e-07,   8.15851990e-07,   1.20728664e-05, ...,
#           8.46010540e-03,   1.59316193e-02,   7.35773574e-05],
#        [  4.26310271e-06,   3.00462648e-06,   1.94857239e-05, ...,
#           5.27153723e-03,   1.45574985e-03,   3.38930317e-04]], dtype=float32)

# %% [markdown]
# # Keras

# %%
X_train = tr.drop(labels = ['VisitNumber', 'TripType'], axis = 1)
X_test = te.drop(labels = ['VisitNumber', 'TripType'], axis = 1)
Y_train = tr['TripType']
Y_test = te['TripType']

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
ss.fit(np.vstack([X_train.as_matrix(), X_test.as_matrix()]))
X_train = ss.transform(X_train.as_matrix())
X_test = ss.transform(X_test.as_matrix())

# %%
# X_train.to_pickle('./Data/X_train')
# X_test.to_pickle('./Data/X_test')
# Y_train.to_pickle('./Data/Y_train')
# Y_test.to_pickle('./Data/Y_test')

# %%
import pandas as pd
X_train = pd.read_pickle('./Data/X_train')
X_test = pd.read_pickle('./Data/X_test')
Y_train = pd.read_pickle('./Data/Y_train')
Y_test = pd.read_pickle('./Data/Y_test')

# %%
from sklearn.preprocessing import OneHotEncoder
Y_train = pd.get_dummies(Y_train, prefix = 'class')
Y_test = pd.get_dummies(Y_test, prefix = 'class')

# %%
Y_test.columns
# Out:
# Index(['class_0', 'class_1', 'class_2', 'class_3', 'class_4', 'class_5',
#        'class_6', 'class_7', 'class_8', 'class_9', 'class_10', 'class_11',
#        'class_12', 'class_13', 'class_14', 'class_15', 'class_16', 'class_17',
#        'class_18', 'class_19', 'class_20', 'class_21', 'class_22', 'class_23',
#        'class_24', 'class_25', 'class_26', 'class_27', 'class_28', 'class_29',
#        'class_30', 'class_31', 'class_32', 'class_33', 'class_34', 'class_35',
#        'class_36'],
#       dtype='object')

# %%
X_test.as_matrix().shape
# Out:
# (28701, 2568)

# %%
from sklearn.metrics import log_loss
# from __future__ import absolute_import
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.optimizers import SGD, Adagrad, Adam
# from . import backend as K
model = Sequential()
# Dense(64) is a fully-connected layer with 64 hidden units.
# in the first layer, you must specify the expected input data shape:
# here, 20-dimensional vectors.
model.add(Dense(1024, input_dim=X_train.shape[1], init='uniform'))
model.add(Activation('sigmoid'))
model.add(Dropout(0.1))
model.add(Dense(512, init='uniform', activation = 'sigmoid'))
model.add(Dropout(0.1))
model.add(Dense(512, init='uniform', activation = 'sigmoid'))
model.add(Dropout(0.1))
model.add(Dense(37, init='uniform', activation = 'sigmoid'))

sgd = SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
ada = Adagrad()
# model.compile(loss='mean_absolute_percentage_error', optimizer=sgd)
model.compile(loss='categorical_crossentropy', optimizer=ada)

# for i in range(10):
#     model.fit(X_train.as_matrix(), Y_train.as_matrix(), nb_epoch=1, batch_size = 128)
#     score_test = model.evaluate(X_test.as_matrix(), Y_test.as_matrix(), batch_size=128)
# #     pred_test = model.predict(X_test.as_matrix(), batch_size = 128)
# #     err = log_loss(pred_test.reshape([1,-1]), Y_test)
# #     err_test = log_loss(pred_test, Y_test)
#     print('Epoch {0}'.format(i))
#     print('Validation error: ', score_test)
#     score_train = model.evaluate(X_train.as_matrix(), Y_train.as_matrix(), batch_size=128)
# #     err_train = log_loss(pred_train, Y_train)
#     print('Train error: ', score_train)

# %%
import numpy as np

# %%
np.vstack([Y_train.as_matrix(), Y_test.as_matrix()]).shape
# Out:
# (94134, 38)

# %%
pred_test_ave
# Out:
# True

# %%
from sklearn.metrics import log_loss
pred_test_ave = True
num = 1
for i in range(num):
    print('Starting iteration {0}'.format(i+1))
    model = Sequential()
    model.add(Dense(512, input_dim=X_train.shape[1]))
    model.add(PReLU())
    model.add(BatchNormalization())
    model.add(Dropout(0.1))

    model.add(Dense(37))
    model.add(Activation('softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam')

    model.fit(np.vstack([X_train.as_matrix(), X_test.as_matrix()]),
              np.vstack([Y_train.as_matrix(), Y_test.as_matrix()]), nb_epoch=4, batch_size = 128, validation_split=0.3)

#     score_test = model.evaluate(X_test.as_matrix(), Y_test.as_matrix(), batch_size=128)
#     score_train = model.evaluate(X_train.as_matrix(), Y_train.as_matrix(), batch_size=128)
    pred_test = model.predict(X_test.as_matrix(), batch_size = 128)
    pred_train = model.predict(X_train.as_matrix(), batch_size = 128)
    #     err_train = log_loss(pred_train, Y_train)
    print('Train error: ', log_loss(Y_train, pred_train))
    print('Validation error: ', log_loss(Y_test, pred_test))
    if i==0:
        score_test_ave = pred_test.copy()/num
    else: 
        score_test_ave += pred_test/num
print('Average validation error: ', log_loss(Y_test, pred_test_ave))
# Out:
# Starting iteration 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-59-29840f2bf821> in <module>()
#      12     model.add(Dense(37))
#      13     model.add(Activation('softmax'))
# ---> 14     model.compile(loss='categorical_crossentropy', optimizer='adam')
#      15
#      16     model.fit(np.vstack([X_train.as_matrix(), X_test.as_matrix()]),
#
# /opt/conda/Anaconda3/lib/python3.4/site-packages/Keras-0.3.0-py3.4.egg/keras/models.py in compile(self, optimizer, loss, class_mode)
#     452
#     453         self._train = K.function(train_ins, [train_loss], updates=updates)
# --> 454         self._train_with_acc = K.function(train_ins, [train_loss, train_accuracy], updates=updates)
#     455         self._predict = K.function(predict_ins, [self.y_test], updates=self.state_updates)
#     456         self._test = K.function(test_ins, [test_loss])
#
# /opt/conda/Anaconda3/lib/python3.4/site-packages/Keras-0.3.0-py3.4.egg/keras/backend/theano_backend.py in function(inputs, outputs, updates)
#     367
#     368 def function(inputs, outputs, updates=[]):
# --> 369     return Function(inputs, outputs, updates=updates)
#     370
#     371
#
# /opt/conda/Anaconda3/lib/python3.4/site-packages/Keras-0.3.0-py3.4.egg/keras/backend/theano_backend.py in __init__(self, inputs, outputs, updates, **kwargs)
#     360     def __init__(self, inputs, outputs, updates=[], **kwargs):
#     361         self.function = theano.function(inputs, outputs, updates=updates,
# --> 362                                         allow_input_downcast=True, **kwargs)
#     363
#     364     def __call__(self, inputs):
#
# /opt/conda/Anaconda3/lib/python3.4/site-packages/theano/compile/function.py in function(inputs, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input)
#     315                    on_unused_input=on_unused_input,
#     316                    profile=profile,
# --> 317                    output_keys=output_keys)
#     318     # We need to add the flag check_aliased inputs if we have any mutable or
#     319     # borrowed used defined inputs
#
# /opt/conda/Anaconda3/lib/python3.4/site-packages/theano/compile/pfunc.py in pfunc(params, outputs, mode, updates, givens, no_default_updates, accept_inplace, name, rebuild_strict, allow_input_downcast, profile, on_unused_input, output_keys)
#     524                          accept_inplace=accept_inplace, name=name,
#     525                          profile=profile, on_unused_input=on_unused_input,
# --> 526                          output_keys=output_keys)
#     527
#     528
#
# /opt/conda/Anaconda3/lib/python3.4/site-packages/theano/compile/function_module.py in orig_function(inputs, outputs, mode, accept_inplace, name, profile, on_unused_input, output_keys)
#    1775                    profile=profile,
#    1776                    on_unused_input=on_unused_input,
# -> 1777                    output_keys=output_keys).create(
#    1778             defaults)
#    1779
#
# /opt/conda/Anaconda3/lib/python3.4/site-packages/theano/compile/function_module.py in __init__(self, inputs, outputs, mode, accept_inplace, function_builder, profile, on_unused_input, fgraph, output_keys)
#    1455                         optimizer, inputs, outputs)
#    1456                 else:
# -> 1457                     optimizer_profile = optimizer(fgraph)
#    1458
#    1459                 end_optimizer = time.time()
#
# /opt/conda/Anaconda3/lib/python3.4/site-packages/theano/gof/opt.py in __call__(self, fgraph)
#      99
#     100         """
# --> 101         return self.optimize(fgraph)
#     102
#     103     def add_requirements(self, fgraph):
#
# /opt/conda/Anaconda3/lib/python3.4/site-packages/theano/gof/opt.py in optimize(self, fgraph, *args, **kwargs)
#      87             orig = theano.tensor.basic.constant.enable
#      88             theano.tensor.basic.constant.enable = False
# ---> 89             ret = self.apply(fgraph, *args, **kwargs)
#      90         finally:
#      91             theano.tensor.basic.constant.enable = orig
#
# /opt/conda/Anaconda3/lib/python3.4/site-packages/theano/gof/opt.py in apply(self, fgraph)
#     228             try:
#     229                 t0 = time.time()
# --> 230                 sub_prof = optimizer.optimize(fgraph)
#     231                 l.append(float(time.time() - t0))
#     232                 sub_profs.append(sub_prof)
#
# /opt/conda/Anaconda3/lib/python3.4/site-packages/theano/gof/opt.py in optimize(self, fgraph, *args, **kwargs)
#      87             orig = theano.tensor.basic.constant.enable
#      88             theano.tensor.basic.constant.enable = False
# ---> 89             ret = self.apply(fgraph, *args, **kwargs)
#      90         finally:
#      91             theano.tensor.basic.constant.enable = orig
#
# /opt/conda/Anaconda3/lib/python3.4/site-packages/theano/tensor/opt.py in inplace_elemwise_optimizer(fgraph)
#     409                         nb_change_no_validate += 1
#     410                         if nb_change_no_validate >= check_each_change:
# --> 411                             fgraph.validate()
#     412                             chk = fgraph.checkpoint()
#     413                             nb_change_no_validate = 0
#
# /opt/conda/Anaconda3/lib/python3.4/site-packages/theano/gof/toolbox.py in validate_(self, fgraph)
#     230         t0 = time.time()
#     231         try:
# --> 232             ret = fgraph.execute_callbacks('validate')
#     233         except Exception as e:
#     234             cf = inspect.currentframe()
#
# /opt/conda/Anaconda3/lib/python3.4/site-packages/theano/gof/fg.py in execute_callbacks(self, name, *args, **kwargs)
#     674                 continue
#     675             tf0 = time.time()
# --> 676             fn(self, *args, **kwargs)
#     677             self.execute_callbacks_times[feature] += time.time() - tf0
#     678         self.execute_callbacks_time += time.time() - t0
#
# /opt/conda/Anaconda3/lib/python3.4/site-packages/theano/gof/destroyhandler.py in validate(self, fgraph)
#     902         """
#     903         if self.destroyers:
# --> 904             ords = self.orderings(fgraph)
#     905
#     906             if _contains_cycle(fgraph, ords):
#
# /opt/conda/Anaconda3/lib/python3.4/site-packages/theano/gof/destroyhandler.py in orderings(self, fgraph)
#    1017                     for r in root_impact:
#    1018                         assert not [a for a, c in self.clients[r].items() if not c]
# -> 1019                         root_clients.update([a for a, c in self.clients[r].items() if c])
#    1020                     root_clients.remove(app)
#    1021                     if root_clients:
#
# /opt/conda/Anaconda3/lib/python3.4/site-packages/theano/misc/ordered_set.py in update(self, iterable)
#      83     def update(self, iterable):
#      84         check_deterministic(iterable)
# ---> 85         self |= iterable
#      86
#      87     def __init__(self, iterable=None):
#
# /opt/conda/Anaconda3/lib/python3.4/_collections_abc.py in __ior__(self, it)
#     366     def __ior__(self, it):
#     367         for value in it:
# --> 368             self.add(value)
#     369         return self
#     370
#
# /opt/conda/Anaconda3/lib/python3.4/site-packages/theano/misc/ordered_set.py in add(self, key)
#     107             last = root.prev
#     108             link.prev, link.next, link.key = last, weakref.ref(root), key
# --> 109             last().next = root.prev = weakref.ref(link)
#     110
#     111     def union(self, s):
#
# KeyboardInterrupt:

# %%
i = 0
for i in range(num):
    print(i)
if i==0:
    score_test_ave = pred_test.copy()/num
else: 
    score_test_ave += pred_test/num
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
score_test_ave
# Out:
# array([[  1.36073341e-04,   5.92093100e-05,   2.86282171e-03, ...,
#           6.49075815e-04,   2.37603020e-04,   1.91079155e-03],
#        [  7.65540288e-05,   2.72357650e-04,   2.84175575e-04, ...,
#           1.62048894e-04,   8.04141091e-06,   7.55302492e-05],
#        [  3.52289426e-06,   7.92741892e-05,   1.53942825e-04, ...,
#           2.16239147e-05,   2.45462925e-06,   1.08990271e-04],
#        ...,
#        [  1.33003541e-06,   2.55940977e-05,   4.76350600e-05, ...,
#           6.43871678e-04,   2.75998493e-04,   9.46114678e-04],
#        [  9.88976812e-10,   9.89618493e-06,   6.23314467e-05, ...,
#           8.21584035e-07,   6.22396474e-06,   6.52766175e-06],
#        [  2.11832143e-05,   9.91156194e-06,   7.10534048e-05, ...,
#           7.89879050e-07,   5.97066219e-07,   1.30793322e-03]])

# %%
print('Average validation error: ', log_loss(Y_test, pred_test_ave))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-628f131c306f> in <module>()
# ----> 1 print('Average validation error: ', log_loss(Y_test, pred_test_ave))
#
# /opt/conda/Anaconda3/lib/python3.4/site-packages/sklearn/metrics/classification.py in log_loss(y_true, y_pred, eps, normalize, sample_weight)
#    1548     # This happens in cases when elements in y_pred have type "str".
#    1549     if not isinstance(Y, np.ndarray):
# -> 1550         raise ValueError("y_pred should be an array of floats.")
#    1551
#    1552     # If y_pred is of single dimension, assume y_true to be binary
#
# ValueError: y_pred should be an array of floats.

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.layers.normalization import BatchNormalization
from keras.layers.advanced_activations import PReLU
from keras.utils import np_utils, generic_utils

model = Sequential()
model.add(Dense(512, input_dim=X_train.shape[1]))
model.add(PReLU())
model.add(BatchNormalization())
model.add(Dropout(0.1))

model.add(Dense(37))
model.add(Activation('softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam')

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam')

# %%
import numpy as np

# %%
np.vstack([X_train.as_matrix(), X_test.as_matrix()]).shape
# Out:
# (95670, 2568)

# %% [markdown]
# # SVM attempt

# %%
from sklearn.svm import SVC
clf = SVC(C=1.0, 
                kernel='rbf', 
                degree=3, 
                gamma='auto', 
                coef0=0.0, 
                shrinking=True, 
                probability=False,
                tol=0.001, 
                cache_size=200, 
                class_weight=None, 
                verbose=False, 
                max_iter=-1, 
                decision_function_shape=None, 
                random_state=None)

# %%
clf.fit(tr.drop(labels = ['VisitNumber', 'TripType'], axis = 1), tr['TripType'])
